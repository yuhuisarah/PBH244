# %%
import cv2
import numpy as np
import pydicom
import json
import os
import shutil
import sys
import random
from matplotlib import image
from scipy.ndimage import label
from zipfile import ZipFile
import re
import pandas as pd
from skimage.transform import resize

# %%
# this varibale should be set as where your train.zip, validate.zip, test.zip store
data_path = '.'

# %%
# Create a ZipFile Object and load train.zip in it
#with ZipFile(os.path.join(data_path, "train.zip"), 'r') as zipObj:
#   # Extract all the contents of zip file in different directory
#   zipObj.extractall()

# %%
study_train = next(os.walk(os.path.join(data_path, "train")))[1]
# load labels in 'train.csv'
# the first column means id
# the second and third columns mean the volume
labels = np.loadtxt(os.path.join(data_path, "train.csv"), delimiter=",",skiprows=1)
labels[0:10]
# Out:
# array([[  1. , 108.3, 246.7],
#        [  2. ,  54.6, 137.2],
#        [  3. ,  32.7,  99.3],
#        [  4. ,  57.7, 154.5],
#        [  5. ,  83.3, 235.5],
#        [  6. , 225.3, 317.9],
#        [  7. ,  64.9, 138. ],
#        [  8. , 158.3, 305.5],
#        [  9. ,  61.4, 152.2],
#        [ 10. , 105.2, 219.3]])

# %%
class Dataset(object):
    dataset_count = 0

    def __init__(self, directory, subdir):
        # deal with any intervening directories
        while True:
            subdirs = next(os.walk(directory))[1]
            if len(subdirs) == 1:
                directory = os.path.join(directory, subdirs[0])
            else:
                break

        slices = []
        for s in subdirs:
            m = re.match("sax_(\d+)", s)
            if m is not None:
                slices.append(int(m.group(1)))

        slices_map = {}
        first = True
        times = []
        for s in slices:
            files = next(os.walk(os.path.join(directory, "sax_%d" % s)))[2]
            offset = None

            for f in files:
                m = re.match("IM-(\d{4,})-(\d{4})\.dcm", f)
                if m is not None:
                    if first:
                        times.append(int(m.group(2)))
                    if offset is None:
                        offset = int(m.group(1))

            first = False
            slices_map[s] = offset

        self.directory = directory
        self.time = sorted(times)
        self.slices = sorted(slices)
        self.slices_map = slices_map
        Dataset.dataset_count += 1
        self.name = subdir

    def _filename(self, s, t):
        return os.path.join(self.directory,"sax_%d" % s, "IM-%04d-%04d.dcm" % (self.slices_map[s], t))

    def _read_dicom_image(self, filename):
        d = pydicom.read_file(filename)
        img = d.pixel_array
        IMG_PX_SIZE = 64
        resized_img = resize(img, (IMG_PX_SIZE, IMG_PX_SIZE), anti_aliasing=True)
        return np.array(resized_img)

    def _read_all_dicom_images(self):
        f1 = self._filename(self.slices[0], self.time[0])
        d1 = pydicom.read_file(f1)
        (x, y) = d1.PixelSpacing
        (x, y) = (float(x), float(y))
        f2 = self._filename(self.slices[1], self.time[0])
        d2 = pydicom.read_file(f2)

        # try a couple of things to measure distance between slices
        try:
            dist = np.abs(d2.SliceLocation - d1.SliceLocation)
        except AttributeError:
            try:
                dist = d1.SliceThickness
            except AttributeError:
                dist = 8  # better than nothing...

        self.images = np.array([[self._read_dicom_image(self._filename(d, i))
                                 for i in self.time]
                                for d in self.slices])
        self.dist = dist
        self.area_multiplier = x * y

    def load(self):
        self._read_all_dicom_images()

# %%
dset = []
for i,s in enumerate(study_train):
    full_path = os.path.join(data_path, "train", s)
    dset.append(Dataset(full_path, s))
    print("Processing dataset %s..." % dset[i].name)
    p_edv = 0
    p_esv = 0
    try:
        dset[i].load()
        print("Dataset %s processing done." % dset[i].name)
    except Exception as e:
        print("ERROR: Exception %s thrown by dataset %s" % (str(e), dset[i].name))
        print("Omit index: %s" % i)
# Out:
# Processing dataset 135...
# /Users/dogspro/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Dataset 135 processing done.
# Processing dataset 307...
# Dataset 307 processing done.
# Processing dataset 61...
# Dataset 61 processing done.
# Processing dataset 95...
# Dataset 95 processing done.
# Processing dataset 338...
# Dataset 338 processing done.
# Processing dataset 300...
# Dataset 300 processing done.
# Processing dataset 132...
# Dataset 132 processing done.
# Processing dataset 59...
# Dataset 59 processing done.
# Processing dataset 92...
# Dataset 92 processing done.
# Processing dataset 66...
# Dataset 66 processing done.
# Processing dataset 336...
# Dataset 336 processing done.
# Processing dataset 104...
# Dataset 104 processing done.
# Processing dataset 309...
# Dataset 309 processing done.
# Processing dataset 50...
# Dataset 50 processing done.
# Processing dataset 68...
# Dataset 68 processing done.
# Processing dataset 103...
# Dataset 103 processing done.
# Processing dataset 331...
# Dataset 331 processing done.
# Processing dataset 57...
# Dataset 57 processing done.
# Processing dataset 168...
# Dataset 168 processing done.
# Processing dataset 391...
# Dataset 391 processing done.
# Processing dataset 365...
# Dataset 365 processing done.
# Processing dataset 157...
# Dataset 157 processing done.
# Processing dataset 150...
# Dataset 150 processing done.
# Processing dataset 362...
# Dataset 362 processing done.
# Processing dataset 396...
# Dataset 396 processing done.
# Processing dataset 159...
# Dataset 159 processing done.
# Processing dataset 32...
# Dataset 32 processing done.
# Processing dataset 166...
# Dataset 166 processing done.
# Processing dataset 354...
# Dataset 354 processing done.
# Processing dataset 192...
# Dataset 192 processing done.
# Processing dataset 398...
# Dataset 398 processing done.
# Processing dataset 35...
# Dataset 35 processing done.
# Processing dataset 195...
# Dataset 195 processing done.
# Processing dataset 353...
# Dataset 353 processing done.
# Processing dataset 161...
# Dataset 161 processing done.
# Processing dataset 330...
# Dataset 330 processing done.
# Processing dataset 102...
# Dataset 102 processing done.
# Processing dataset 69...
# Dataset 69 processing done.
# Processing dataset 56...
# Dataset 56 processing done.
# Processing dataset 105...
# Dataset 105 processing done.
# Processing dataset 337...
# Dataset 337 processing done.
# Processing dataset 51...
# Dataset 51 processing done.
# Processing dataset 308...
# Dataset 308 processing done.
# Processing dataset 58...
# Dataset 58 processing done.
# Processing dataset 133...
# Dataset 133 processing done.
# Processing dataset 301...
# Dataset 301 processing done.
# Processing dataset 67...
# Dataset 67 processing done.
# Processing dataset 93...
# Dataset 93 processing done.
# Processing dataset 306...
# Dataset 306 processing done.
# Processing dataset 134...
# Dataset 134 processing done.
# Processing dataset 94...
# Dataset 94 processing done.
# Processing dataset 339...
# Dataset 339 processing done.
# Processing dataset 60...
# Dataset 60 processing done.
# Processing dataset 399...
# Dataset 399 processing done.
# Processing dataset 34...
# Dataset 34 processing done.
# Processing dataset 160...
# Dataset 160 processing done.
# Processing dataset 352...
# Dataset 352 processing done.
# Processing dataset 194...
# Dataset 194 processing done.
# Processing dataset 33...
# Dataset 33 processing done.
# Processing dataset 158...
# Dataset 158 processing done.
# Processing dataset 193...
# Dataset 193 processing done.
# Processing dataset 355...
# Dataset 355 processing done.
# Processing dataset 167...
# Dataset 167 processing done.
# Processing dataset 397...
# Dataset 397 processing done.
# Processing dataset 363...
# Dataset 363 processing done.
# Processing dataset 151...
# Dataset 151 processing done.
# Processing dataset 169...
# Dataset 169 processing done.
# Processing dataset 156...
# Dataset 156 processing done.
# Processing dataset 364...
# Dataset 364 processing done.
# Processing dataset 390...
# Dataset 390 processing done.
# Processing dataset 216...
# Dataset 216 processing done.
# Processing dataset 440...
# Dataset 440 processing done.
# Processing dataset 229...
# Dataset 229 processing done.
# Processing dataset 447...
# Dataset 447 processing done.
# Processing dataset 211...
# Dataset 211 processing done.
# Processing dataset 478...
# Dataset 478 processing done.
# Processing dataset 227...
# Dataset 227 processing done.
# Processing dataset 471...
# Dataset 471 processing done.
# Processing dataset 485...
# Dataset 485 processing done.
# Processing dataset 218...
# Dataset 218 processing done.
# Processing dataset 482...
# Dataset 482 processing done.
# Processing dataset 476...
# Dataset 476 processing done.
# Processing dataset 220...
# Dataset 220 processing done.
# Processing dataset 449...
# Dataset 449 processing done.
# Processing dataset 280...
# Dataset 280 processing done.
# Processing dataset 422...
# Dataset 422 processing done.
# Processing dataset 274...
# Dataset 274 processing done.
# Processing dataset 273...
# Dataset 273 processing done.
# Processing dataset 425...
# Dataset 425 processing done.
# Processing dataset 287...
# Dataset 287 processing done.
# Processing dataset 413...
# Dataset 413 processing done.
# Processing dataset 245...
# Dataset 245 processing done.
# Processing dataset 289...
# Dataset 289 processing done.
# Processing dataset 242...
# Dataset 242 processing done.
# Processing dataset 414...
# Dataset 414 processing done.
# Processing dataset 477...
# Dataset 477 processing done.
# Processing dataset 221...
# Dataset 221 processing done.
# Processing dataset 483...
# Dataset 483 processing done.
# Processing dataset 448...
# Dataset 448 processing done.
# Processing dataset 484...
# Dataset 484 processing done.
# Processing dataset 226...
# Dataset 226 processing done.
# Processing dataset 470...
# Dataset 470 processing done.
# Processing dataset 219...
# Dataset 219 processing done.
# Processing dataset 446...
# Dataset 446 processing done.
# Processing dataset 210...
# Dataset 210 processing done.
# Processing dataset 479...
# Dataset 479 processing done.
# Processing dataset 217...
# Dataset 217 processing done.
# Processing dataset 441...
# Dataset 441 processing done.
# Processing dataset 228...
# Dataset 228 processing done.
# Processing dataset 288...
# Dataset 288 processing done.
# Processing dataset 243...
# Dataset 243 processing done.
# Processing dataset 415...
# Dataset 415 processing done.
# Processing dataset 412...
# Dataset 412 processing done.
# Processing dataset 244...
# Dataset 244 processing done.
# Processing dataset 286...
# Dataset 286 processing done.
# Processing dataset 272...
# Dataset 272 processing done.
# Processing dataset 424...
# Dataset 424 processing done.
# Processing dataset 423...
# Dataset 423 processing done.
# Processing dataset 275...
# Dataset 275 processing done.
# Processing dataset 281...
# Dataset 281 processing done.
# Processing dataset 257...
# Dataset 257 processing done.
# Processing dataset 401...
# Dataset 401 processing done.
# Processing dataset 268...
# Dataset 268 processing done.
# Processing dataset 406...
# Dataset 406 processing done.
# Processing dataset 250...
# Dataset 250 processing done.
# Processing dataset 439...
# Dataset 439 processing done.
# Processing dataset 292...
# Dataset 292 processing done.
# Processing dataset 266...
# Dataset 266 processing done.
# Processing dataset 430...
# Dataset 430 processing done.
# Processing dataset 259...
# Dataset 259 processing done.
# Processing dataset 437...
# Dataset 437 processing done.
# Processing dataset 261...
# Dataset 261 processing done.
# Processing dataset 295...
# Dataset 295 processing done.
# Processing dataset 408...
# Dataset 408 processing done.
# Processing dataset 463...
# ERROR: Exception list index out of range thrown by dataset 463
# Omit index: 134
# Processing dataset 235...
# Dataset 235 processing done.
# Processing dataset 497...
# Dataset 497 processing done.
# Processing dataset 490...
# Dataset 490 processing done.
# Processing dataset 232...
# Dataset 232 processing done.
# Processing dataset 464...
# Dataset 464 processing done.
# Processing dataset 499...
# ERROR: Exception list index out of range thrown by dataset 499
# Omit index: 140
# Processing dataset 452...
# Dataset 452 processing done.
# Processing dataset 204...
# Dataset 204 processing done.
# Processing dataset 203...
# Dataset 203 processing done.
# Processing dataset 455...
# Dataset 455 processing done.
# Processing dataset 294...
# Dataset 294 processing done.
# Processing dataset 436...
# Dataset 436 processing done.
# Processing dataset 260...
# Dataset 260 processing done.
# Processing dataset 409...
# Dataset 409 processing done.
# Processing dataset 267...
# Dataset 267 processing done.
# Processing dataset 431...
# Dataset 431 processing done.
# Processing dataset 293...
# Dataset 293 processing done.
# Processing dataset 258...
# Dataset 258 processing done.
# Processing dataset 407...
# Dataset 407 processing done.
# Processing dataset 251...
# Dataset 251 processing done.
# Processing dataset 438...
# Dataset 438 processing done.
# Processing dataset 256...
# Dataset 256 processing done.
# Processing dataset 400...
# Dataset 400 processing done.
# Processing dataset 269...
# Dataset 269 processing done.
# Processing dataset 202...
# Dataset 202 processing done.
# Processing dataset 454...
# Dataset 454 processing done.
# Processing dataset 498...
# Dataset 498 processing done.
# Processing dataset 453...
# Dataset 453 processing done.
# Processing dataset 205...
# Dataset 205 processing done.
# Processing dataset 233...
# Dataset 233 processing done.
# Processing dataset 465...
# Dataset 465 processing done.
# Processing dataset 491...
# Dataset 491 processing done.
# Processing dataset 496...
# Dataset 496 processing done.
# Processing dataset 462...
# Dataset 462 processing done.
# Processing dataset 234...
# ERROR: Exception list index out of range thrown by dataset 234
# Omit index: 169
# Processing dataset 346...
# Dataset 346 processing done.
# Processing dataset 174...
# Dataset 174 processing done.
# Processing dataset 180...
# Dataset 180 processing done.
# Processing dataset 379...
# Dataset 379 processing done.
# Processing dataset 20...
# Dataset 20 processing done.
# Processing dataset 187...
# Dataset 187 processing done.
# Processing dataset 18...
# Dataset 18 processing done.
# Processing dataset 173...
# Dataset 173 processing done.
# Processing dataset 341...
# Dataset 341 processing done.
# Processing dataset 27...
# Dataset 27 processing done.
# Processing dataset 9...
# Dataset 9 processing done.
# Processing dataset 383...
# Dataset 383 processing done.
# Processing dataset 145...
# Dataset 145 processing done.
# Processing dataset 377...
# Dataset 377 processing done.
# Processing dataset 11...
# Dataset 11 processing done.
# Processing dataset 348...
# Dataset 348 processing done.
# Processing dataset 370...
# Dataset 370 processing done.
# Processing dataset 142...
# Dataset 142 processing done.
# Processing dataset 384...
# Dataset 384 processing done.
# Processing dataset 7...
# Dataset 7 processing done.
# Processing dataset 29...
# Dataset 29 processing done.
# Processing dataset 16...
# Dataset 16 processing done.
# Processing dataset 189...
# Dataset 189 processing done.
# Processing dataset 129...
# Dataset 129 processing done.
# Processing dataset 42...
# Dataset 42 processing done.
# Processing dataset 89...
# Dataset 89 processing done.
# Processing dataset 116...
# Dataset 116 processing done.
# Processing dataset 324...
# Dataset 324 processing done.
# Processing dataset 45...
# Dataset 45 processing done.
# Processing dataset 323...
# Dataset 323 processing done.
# Processing dataset 111...
# Dataset 111 processing done.
# Processing dataset 73...
# Dataset 73 processing done.
# Processing dataset 118...
# Dataset 118 processing done.
# Processing dataset 87...
# Dataset 87 processing done.
# Processing dataset 315...
# Dataset 315 processing done.
# Processing dataset 127...
# Dataset 127 processing done.
# Processing dataset 80...
# Dataset 80 processing done.
# Processing dataset 74...
# Dataset 74 processing done.
# Processing dataset 120...
# Dataset 120 processing done.
# Processing dataset 312...
# Dataset 312 processing done.
# Processing dataset 6...
# Dataset 6 processing done.
# Processing dataset 385...
# Dataset 385 processing done.
# Processing dataset 28...
# Dataset 28 processing done.
# Processing dataset 143...
# Dataset 143 processing done.
# Processing dataset 371...
# Dataset 371 processing done.
# Processing dataset 17...
# Dataset 17 processing done.
# Processing dataset 188...
# Dataset 188 processing done.
# Processing dataset 376...
# Dataset 376 processing done.
# Processing dataset 144...
# Dataset 144 processing done.
# Processing dataset 382...
# Dataset 382 processing done.
# Processing dataset 1...
# Dataset 1 processing done.
# Processing dataset 349...
# Dataset 349 processing done.
# Processing dataset 10...
# Dataset 10 processing done.
# Processing dataset 340...
# Dataset 340 processing done.
# Processing dataset 172...
# Dataset 172 processing done.
# Processing dataset 186...
# Dataset 186 processing done.
# Processing dataset 19...
# Dataset 19 processing done.
# Processing dataset 26...
# Dataset 26 processing done.
# Processing dataset 8...
# Dataset 8 processing done.
# Processing dataset 181...
# Dataset 181 processing done.
# Processing dataset 175...
# Dataset 175 processing done.
# Processing dataset 347...
# Dataset 347 processing done.
# Processing dataset 21...
# Dataset 21 processing done.
# Processing dataset 378...
# Dataset 378 processing done.
# Processing dataset 75...
# Dataset 75 processing done.
# Processing dataset 81...
# Dataset 81 processing done.
# Processing dataset 313...
# Dataset 313 processing done.
# Processing dataset 121...
# Dataset 121 processing done.
# Processing dataset 119...
# Dataset 119 processing done.
# Processing dataset 86...
# Dataset 86 processing done.
# Processing dataset 72...
# Dataset 72 processing done.
# Processing dataset 126...
# Dataset 126 processing done.
# Processing dataset 314...
# Dataset 314 processing done.
# Processing dataset 44...
# Dataset 44 processing done.
# Processing dataset 110...
# Dataset 110 processing done.
# Processing dataset 322...
# Dataset 322 processing done.
# Processing dataset 43...
# Dataset 43 processing done.
# Processing dataset 128...
# Dataset 128 processing done.
# Processing dataset 88...
# Dataset 88 processing done.
# Processing dataset 325...
# Dataset 325 processing done.
# Processing dataset 117...
# Dataset 117 processing done.
# Processing dataset 198...
# Dataset 198 processing done.
# Processing dataset 361...
# Dataset 361 processing done.
# Processing dataset 153...
# Dataset 153 processing done.
# Processing dataset 38...
# Dataset 38 processing done.
# Processing dataset 395...
# Dataset 395 processing done.
# Processing dataset 359...
# Dataset 359 processing done.
# Processing dataset 392...
# Dataset 392 processing done.
# Processing dataset 154...
# Dataset 154 processing done.
# Processing dataset 366...
# Dataset 366 processing done.
# Processing dataset 36...
# Dataset 36 processing done.
# Processing dataset 196...
# Dataset 196 processing done.
# Processing dataset 162...
# Dataset 162 processing done.
# Processing dataset 350...
# Dataset 350 processing done.
# Processing dataset 368...
# Dataset 368 processing done.
# Processing dataset 31...
# Dataset 31 processing done.
# Processing dataset 357...
# Dataset 357 processing done.
# Processing dataset 165...
# Dataset 165 processing done.
# Processing dataset 191...
# Dataset 191 processing done.
# Processing dataset 131...
# Dataset 131 processing done.
# Processing dataset 303...
# Dataset 303 processing done.
# Processing dataset 91...
# Dataset 91 processing done.
# Processing dataset 65...
# Dataset 65 processing done.
# Processing dataset 304...
# Dataset 304 processing done.
# Processing dataset 136...
# Dataset 136 processing done.
# Processing dataset 62...
# Dataset 62 processing done.
# Processing dataset 96...
# Dataset 96 processing done.
# Processing dataset 109...
# Dataset 109 processing done.
# Processing dataset 332...
# Dataset 332 processing done.
# Processing dataset 100...
# Dataset 100 processing done.
# Processing dataset 54...
# Dataset 54 processing done.
# Processing dataset 107...
# Dataset 107 processing done.
# Processing dataset 335...
# Dataset 335 processing done.
# Processing dataset 98...
# Dataset 98 processing done.
# Processing dataset 138...
# Dataset 138 processing done.
# Processing dataset 53...
# Dataset 53 processing done.
# Processing dataset 30...
# Dataset 30 processing done.
# Processing dataset 369...
# Dataset 369 processing done.
# Processing dataset 190...
# Dataset 190 processing done.
# Processing dataset 500...
# Dataset 500 processing done.
# Processing dataset 164...
# Dataset 164 processing done.
# Processing dataset 356...
# Dataset 356 processing done.
# Processing dataset 37...
# Dataset 37 processing done.
# Processing dataset 351...
# Dataset 351 processing done.
# Processing dataset 163...
# Dataset 163 processing done.
# Processing dataset 197...
# Dataset 197 processing done.
# Processing dataset 358...
# Dataset 358 processing done.
# Processing dataset 367...
# Dataset 367 processing done.
# Processing dataset 155...
# Dataset 155 processing done.
# Processing dataset 393...
# Dataset 393 processing done.
# Processing dataset 199...
# Dataset 199 processing done.
# Processing dataset 39...
# Dataset 39 processing done.
# Processing dataset 394...
# Dataset 394 processing done.
# Processing dataset 152...
# Dataset 152 processing done.
# Processing dataset 360...
# Dataset 360 processing done.
# Processing dataset 334...
# ERROR: Exception %d format: a number is required, not NoneType thrown by dataset 334
# Omit index: 305
# Processing dataset 106...
# Dataset 106 processing done.
# Processing dataset 99...
# Dataset 99 processing done.
# Processing dataset 52...
# Dataset 52 processing done.
# Processing dataset 139...
# Dataset 139 processing done.
# Processing dataset 101...
# Dataset 101 processing done.
# Processing dataset 333...
# Dataset 333 processing done.
# Processing dataset 55...
# Dataset 55 processing done.
# Processing dataset 137...
# Dataset 137 processing done.
# Processing dataset 305...
# Dataset 305 processing done.
# Processing dataset 97...
# Dataset 97 processing done.
# Processing dataset 108...
# Dataset 108 processing done.
# Processing dataset 63...
# Dataset 63 processing done.
# Processing dataset 302...
# Dataset 302 processing done.
# Processing dataset 130...
# Dataset 130 processing done.
# Processing dataset 64...
# Dataset 64 processing done.
# Processing dataset 90...
# Dataset 90 processing done.
# Processing dataset 419...
# Dataset 419 processing done.
# Processing dataset 270...
# Dataset 270 processing done.
# Processing dataset 426...
# Dataset 426 processing done.
# Processing dataset 284...
# Dataset 284 processing done.
# Processing dataset 248...
# Dataset 248 processing done.
# Processing dataset 283...
# Dataset 283 processing done.
# Processing dataset 421...
# Dataset 421 processing done.
# Processing dataset 277...
# Dataset 277 processing done.
# Processing dataset 428...
# Dataset 428 processing done.
# Processing dataset 241...
# Dataset 241 processing done.
# Processing dataset 417...
# Dataset 417 processing done.
# Processing dataset 279...
# ERROR: Exception list index out of range thrown by dataset 279
# Omit index: 333
# Processing dataset 410...
# Dataset 410 processing done.
# Processing dataset 246...
# Dataset 246 processing done.
# Processing dataset 444...
# Dataset 444 processing done.
# Processing dataset 212...
# Dataset 212 processing done.
# Processing dataset 215...
# Dataset 215 processing done.
# Processing dataset 443...
# Dataset 443 processing done.
# Processing dataset 488...
# Dataset 488 processing done.
# Processing dataset 481...
# Dataset 481 processing done.
# Processing dataset 475...
# Dataset 475 processing done.
# Processing dataset 223...
# Dataset 223 processing done.
# Processing dataset 224...
# Dataset 224 processing done.
# Processing dataset 472...
# Dataset 472 processing done.
# Processing dataset 486...
# Dataset 486 processing done.
# Processing dataset 278...
# Dataset 278 processing done.
# Processing dataset 411...
# Dataset 411 processing done.
# Processing dataset 247...
# Dataset 247 processing done.
# Processing dataset 429...
# Dataset 429 processing done.
# Processing dataset 240...
# Dataset 240 processing done.
# Processing dataset 416...
# ERROR: Exception [Errno 2] No such file or directory: './train/416/study/sax_7/IM-5248-0024.dcm' thrown by dataset 416
# Omit index: 352
# Processing dataset 249...
# Dataset 249 processing done.
# Processing dataset 420...
# Dataset 420 processing done.
# Processing dataset 276...
# Dataset 276 processing done.
# Processing dataset 282...
# Dataset 282 processing done.
# Processing dataset 418...
# Dataset 418 processing done.
# Processing dataset 285...
# Dataset 285 processing done.
# Processing dataset 271...
# Dataset 271 processing done.
# Processing dataset 427...
# Dataset 427 processing done.
# Processing dataset 487...
# Dataset 487 processing done.
# Processing dataset 225...
# Dataset 225 processing done.
# Processing dataset 473...
# Dataset 473 processing done.
# Processing dataset 474...
# Dataset 474 processing done.
# Processing dataset 222...
# Dataset 222 processing done.
# Processing dataset 480...
# Dataset 480 processing done.
# Processing dataset 214...
# Dataset 214 processing done.
# Processing dataset 442...
# Dataset 442 processing done.
# Processing dataset 489...
# Dataset 489 processing done.
# Processing dataset 445...
# Dataset 445 processing done.
# Processing dataset 213...
# Dataset 213 processing done.
# Processing dataset 458...
# Dataset 458 processing done.
# Processing dataset 493...
# Dataset 493 processing done.
# Processing dataset 231...
# Dataset 231 processing done.
# Processing dataset 467...
# Dataset 467 processing done.
# Processing dataset 209...
# Dataset 209 processing done.
# Processing dataset 460...
# Dataset 460 processing done.
# Processing dataset 236...
# Dataset 236 processing done.
# Processing dataset 494...
# Dataset 494 processing done.
# Processing dataset 469...
# Dataset 469 processing done.
# Processing dataset 200...
# Dataset 200 processing done.
# Processing dataset 456...
# Dataset 456 processing done.
# Processing dataset 238...
# Dataset 238 processing done.
# Processing dataset 451...
# Dataset 451 processing done.
# Processing dataset 207...
# Dataset 207 processing done.
# Processing dataset 405...
# Dataset 405 processing done.
# Processing dataset 253...
# Dataset 253 processing done.
# Processing dataset 298...
# Dataset 298 processing done.
# Processing dataset 254...
# Dataset 254 processing done.
# Processing dataset 402...
# Dataset 402 processing done.
# Processing dataset 434...
# Dataset 434 processing done.
# Processing dataset 262...
# Dataset 262 processing done.
# Processing dataset 296...
# Dataset 296 processing done.
# Processing dataset 291...
# Dataset 291 processing done.
# Processing dataset 265...
# Dataset 265 processing done.
# Processing dataset 433...
# Dataset 433 processing done.
# Processing dataset 239...
# Dataset 239 processing done.
# Processing dataset 450...
# Dataset 450 processing done.
# Processing dataset 206...
# Dataset 206 processing done.
# Processing dataset 468...
# Dataset 468 processing done.
# Processing dataset 201...
# Dataset 201 processing done.
# Processing dataset 457...
# Dataset 457 processing done.
# Processing dataset 208...
# Dataset 208 processing done.
# Processing dataset 495...
# Dataset 495 processing done.
# Processing dataset 461...
# Dataset 461 processing done.
# Processing dataset 237...
# Dataset 237 processing done.
# Processing dataset 459...
# Dataset 459 processing done.
# Processing dataset 230...
# Dataset 230 processing done.
# Processing dataset 466...
# Dataset 466 processing done.
# Processing dataset 492...
# Dataset 492 processing done.
# Processing dataset 264...
# Dataset 264 processing done.
# Processing dataset 432...
# Dataset 432 processing done.
# Processing dataset 290...
# Dataset 290 processing done.
# Processing dataset 297...
# Dataset 297 processing done.
# Processing dataset 435...
# Dataset 435 processing done.
# Processing dataset 263...
# Dataset 263 processing done.
# Processing dataset 255...
# Dataset 255 processing done.
# Processing dataset 403...
# Dataset 403 processing done.
# Processing dataset 404...
# Dataset 404 processing done.
# Processing dataset 252...
# Dataset 252 processing done.
# Processing dataset 299...
# Dataset 299 processing done.
# Processing dataset 46...
# Dataset 46 processing done.
# Processing dataset 79...
# Dataset 79 processing done.
# Processing dataset 112...
# Dataset 112 processing done.
# Processing dataset 320...
# Dataset 320 processing done.
# Processing dataset 318...
# Dataset 318 processing done.
# Processing dataset 41...
# Dataset 41 processing done.
# Processing dataset 327...
# Dataset 327 processing done.
# Processing dataset 115...
# Dataset 115 processing done.
# Processing dataset 83...
# Dataset 83 processing done.
# Processing dataset 77...
# Dataset 77 processing done.
# Processing dataset 311...
# Dataset 311 processing done.
# Processing dataset 123...
# ERROR: Exception %d format: a number is required, not NoneType thrown by dataset 123
# Omit index: 433
# Processing dataset 48...
# Dataset 48 processing done.
# Processing dataset 70...
# Dataset 70 processing done.
# Processing dataset 329...
# Dataset 329 processing done.
# Processing dataset 84...
# Dataset 84 processing done.
# Processing dataset 124...
# Dataset 124 processing done.
# Processing dataset 316...
# Dataset 316 processing done.
# Processing dataset 184...
# Dataset 184 processing done.
# Processing dataset 342...
# Dataset 342 processing done.
# Processing dataset 170...
# Dataset 170 processing done.
# Processing dataset 24...
# Dataset 24 processing done.
# Processing dataset 389...
# Dataset 389 processing done.
# Processing dataset 177...
# Dataset 177 processing done.
# Processing dataset 345...
# Dataset 345 processing done.
# Processing dataset 183...
# Dataset 183 processing done.
# Processing dataset 148...
# Dataset 148 processing done.
# Processing dataset 23...
# Dataset 23 processing done.
# Processing dataset 141...
# Dataset 141 processing done.
# Processing dataset 373...
# Dataset 373 processing done.
# Processing dataset 4...
# Dataset 4 processing done.
# Processing dataset 387...
# Dataset 387 processing done.
# Processing dataset 15...
# Dataset 15 processing done.
# Processing dataset 380...
# Dataset 380 processing done.
# Processing dataset 3...
# Dataset 3 processing done.
# Processing dataset 374...
# Dataset 374 processing done.
# Processing dataset 146...
# Dataset 146 processing done.
# Processing dataset 12...
# Dataset 12 processing done.
# Processing dataset 179...
# Dataset 179 processing done.
# Processing dataset 328...
# Dataset 328 processing done.
# Processing dataset 85...
# Dataset 85 processing done.
# Processing dataset 71...
# Dataset 71 processing done.
# Processing dataset 317...
# Dataset 317 processing done.
# Processing dataset 125...
# Dataset 125 processing done.
# Processing dataset 76...
# Dataset 76 processing done.
# Processing dataset 82...
# Dataset 82 processing done.
# Processing dataset 49...
# Dataset 49 processing done.
# Processing dataset 122...
# Dataset 122 processing done.
# Processing dataset 310...
# Dataset 310 processing done.
# Processing dataset 40...
# Dataset 40 processing done.
# Processing dataset 319...
# Dataset 319 processing done.
# Processing dataset 114...
# Dataset 114 processing done.
# Processing dataset 326...
# Dataset 326 processing done.
# Processing dataset 47...
# Dataset 47 processing done.
# Processing dataset 321...
# Dataset 321 processing done.
# Processing dataset 113...
# Dataset 113 processing done.
# Processing dataset 78...
# Dataset 78 processing done.
# Processing dataset 147...
# Dataset 147 processing done.
# Processing dataset 375...
# Dataset 375 processing done.
# Processing dataset 2...
# Dataset 2 processing done.
# Processing dataset 381...
# Dataset 381 processing done.
# Processing dataset 178...
# Dataset 178 processing done.
# Processing dataset 13...
# Dataset 13 processing done.
# Processing dataset 386...
# Dataset 386 processing done.
# Processing dataset 5...
# Dataset 5 processing done.
# Processing dataset 372...
# Dataset 372 processing done.
# Processing dataset 140...
# Dataset 140 processing done.
# Processing dataset 14...
# Dataset 14 processing done.
# Processing dataset 182...
# Dataset 182 processing done.
# Processing dataset 344...
# Dataset 344 processing done.
# Processing dataset 176...
# Dataset 176 processing done.
# Processing dataset 22...
# Dataset 22 processing done.
# Processing dataset 149...
# Dataset 149 processing done.
# Processing dataset 171...
# Dataset 171 processing done.
# Processing dataset 343...
# Dataset 343 processing done.
# Processing dataset 185...
# Dataset 185 processing done.
# Processing dataset 25...
# Dataset 25 processing done.
# Processing dataset 388...
# Dataset 388 processing done.

# %%
# note 337, 437, 463, 499, 234, 393, 334, 305, 279, 416, 41, 123 can not loaded 
# so we just remove them from our training data
omit_subject = [463, 499, 234, 334, 279, 416, 123]
omit_index = [134, 140, 169, 305, 333, 352, 433]

# %%
# refine the whole dataset
study_index = [int(ele) for ele in study_train]
study_index = [study_index[i] for i in range(len(study_index)) if i not in omit_index]
X = []
for ind, val in enumerate(study_train):
    try:
        new_image = dset[ind].images
        X.append(new_image)
    except Exception as e:
        print("ERROR: Exception %s" % str(e))
        print("Stop at index: %s" % val)
# Out:
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 463
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 499
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 234
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 334
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 279
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 416
# ERROR: Exception 'Dataset' object has no attribute 'images'
# Stop at index: 123

# %%
# For example, to simplify this problem, we may just take the average of images
# for each subject
# Of course, you can consider more complicated method to obtain better performance
X_train_average = []
for i in range(len(X)):
    images = X[i]
    t, s, w, h = X[i].shape
    image_sum = np.zeros([64,64])
    for j in range(t):
        for k in range(s):
            image_sum = image_sum + images[j,k,:,:]
            
    image_average = image_sum / (t*s)  
    X_train_average.append(image_average)
X_train_average
# Out:
# [array([[3.97517083e-05, 8.01098650e-05, 9.76968658e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [9.10259345e-05, 1.51416448e-04, 1.28527915e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [6.19751043e-05, 1.34670650e-04, 1.33027370e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [6.01166337e-05, 2.32406641e-04, 2.36045331e-04, ...,
#          2.85578464e-04, 2.75288405e-04, 1.72270445e-04],
#         [2.87965131e-05, 1.22796001e-04, 1.82110557e-04, ...,
#          2.06622807e-04, 1.67340607e-04, 1.02039818e-04],
#         [1.81347606e-05, 6.00383823e-05, 1.26415128e-04, ...,
#          3.64064612e-05, 1.23637203e-05, 3.48218705e-06]]),
#  array([[7.49716013e-05, 1.04846965e-04, 1.06214449e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.32330688e-04, 1.80443762e-04, 1.81243801e-04, ...,
#          1.33369679e-04, 7.29269983e-05, 1.08890076e-05],
#         [1.37066283e-04, 1.85568780e-04, 1.86729101e-04, ...,
#          2.84537313e-04, 1.95637085e-04, 3.61278536e-05],
#         ...,
#         [1.64648025e-04, 2.20472203e-04, 2.20732878e-04, ...,
#          3.51030090e-04, 2.93550202e-04, 1.88849470e-04],
#         [1.64857837e-04, 2.20443592e-04, 2.20284644e-04, ...,
#          3.26092716e-04, 2.76626463e-04, 1.67405776e-04],
#         [1.33472996e-04, 1.85938599e-04, 1.87131770e-04, ...,
#          1.20071548e-04, 8.47548596e-05, 3.52917864e-05]]),
#  array([[4.76960033e-05, 6.58681112e-05, 6.73708936e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.05923044e-04, 1.41481189e-04, 1.43192049e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1
#         [3.24821538e-04, 9.99593093e-04, 1.45827342e-03, ...,
#          5.21144505e-04, 3.17798475e-04, 1.32440485e-04],
#         [1.13660150e-04, 5.20723904e-04, 1.01842233e-03, ...,
#          3.54185374e-05, 5.30153197e-06, 0.00000000e+00]]),
#  array([[1.31397133e-05, 2.40470882e-05, 2.61946543e-05, ...,
#          4.80376615e-05, 1.38461495e-06, 0.00000000e+00],
#         [5.49889937e-05, 1.78897903e-04, 2.60335868e-04, ...,
#          5.82753349e-04, 1.54285666e-05, 0.00000000e+00],
#         [8.50831758e-05, 2.00458336e-04, 2.82320163e-04, ...,
#          8.02539779e-04, 2.77770713e-05, 0.00000000e+00],
#         ...,
#         [3.00659246e-05, 3.84301292e-05, 4.48728274e-05, ...,
#          4.59070500e-04, 5.35139549e-04, 2.93340567e-04],
#         [3.00094097e-05, 4.17362506e-05, 4.65965317e-05, ...,
#          5.75943304e-04, 4.69130151e-04, 2.43692231e-04],
#         [1.75196177e-05, 2.66467734e-05, 3.32872737e-05, ...,
#          5.50850690e-04, 3.46012450e-04, 1.96361006e-04]]),
#  array([[3.91563456e-04, 5.26860117e-04, 3.85798937e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [6.78546098e-04, 8.85588419e-04, 7.41447177e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [5.45001399e-04, 9.51145698e-04, 9.38740679e-04, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [1.12905459e-03, 1.84091622e-03, 2.02543735e-03, ...,
#          4.54294991e-04, 5.02869544e-04, 3.36122343e-04],
#         [4.55425289e-04, 1.47625385e-03, 1.78117997e-03, ...,
#          4.04053248e-04, 3.75174137e-04, 2.36684384e-04],
#         [8.81632376e-05, 7.90021730e-04, 1.43203095e-03, ...,
#          1.89183614e-04, 1.22072175e-04, 4.52401742e-05]]),
#  array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          7.31970656e-05, 1.95592917e-05, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.87200455e-04, 8.63290724e-05, 5.71057335e-06],
#         [0.00000000e+00, 0.00000000e+00, 3.23676222e-06, ...,
#          2.57461315e-04, 1.87755329e-04, 4.93143844e-05],
#         ...,
#         [3.41709612e-05, 6.88043169e-05, 8.11733725e-05, ...,
#          1.87986526e-04, 1.76357302e-04, 1.20592512e-04],
#         [4.13611972e-05, 7.96243506e-05, 8.97045530e-05, ...,
#          1.82946425e-04, 1.71941433e-04, 1.14211467e-04],
#         [1.55595784e-05, 3.63210961e-05, 5.05628498e-05, ...,
#          1.50578802e-04, 1.40637318e-04, 9.40741820e-05]]),
#  array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.22534570e-06, 1.54439797e-05, 1.86807420e-05, ...,
#          2.34914055e-20, 0.00000000e+00, 0.00000000e+00],
#         [1.38718381e-06, 1.56520573e-05, 2.30734907e-05, ...,
#          9.12535749e-05, 6.09204889e-05, 1.91200168e-05],
#         ...,
#         [7.06446474e-04, 9.26060791e-04, 1.08322872e-03, ...,
#          8.21605850e-04, 3.29063119e-04, 1.04269983e-05],
#         [6.72992225e-04, 8.40355951e-04, 9.40025108e-04, ...,
#          5.97043911e-04, 1.43804722e-04, 1.38718381e-06],
#         [5.35083035e-04, 7.75273911e-04, 7.89191989e-04, ...,
#          1.20291956e-04, 3.47489544e-05, 0.00000000e+00]]),
#  array([[0.00000000e+00, 1.52590219e-06, 3.05180438e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1
#          1.78021922e-07, 2.54317032e-08, 0.00000000e+00],
#         [9.86750083e-06, 9.52162966e-05, 1.74436052e-04, ...,
#          3.68759696e-06, 7.62951095e-07, 0.00000000e+00],
#         [3.88596424e-05, 1.34584573e-04, 2.07548129e-04, ...,
#          1.45723659e-05, 3.02637268e-06, 6.35792579e-07],
#         ...,
#         [0.00000000e+00, 1.59965413e-05, 2.69830371e-05, ...,
#          7.65494265e-06, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 2.36514839e-06, 6.02731365e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  array([[1.86562736e-04, 6.12119902e-04, 3.77872723e-04, ...,
#          3.82959063e-05, 1.14654595e-05, 0.00000000e+00],
#         [3.92665497e-04, 1.32863695e-03, 1.02470690e-03, ...,
#          1.56104033e-03, 4.97571272e-04, 1.19317074e-05],
#         [3.19146682e-04, 1.11706637e-03, 1.14285835e-03, ...,
#          1.98850487e-03, 6.42426015e-04, 1.64246416e-05],
#         ...,
#         [2.04301349e-05, 2.38846079e-05, 2.85258937e-05, ...,
#          9.62907861e-04, 1.29335046e-03, 4.72372693e-04],
#         [1.08296669e-05, 1.77174199e-05, 2.31428499e-05, ...,
#          1.02203657e-03, 6.22419742e-04, 2.40605105e-04],
#         [9.32495783e-07, 4.36577571e-06, 9.43092326e-06, ...,
#          4.85173317e-04, 3.32561905e-04, 2.16974814e-04]]),
#  array([[1.50458869e-05, 7.17600299e-05, 7.86749967e-05, ...,
#          1.30304244e-04, 1.28319560e-04, 1.05676674e-04],
#         [3.19334048e-05, 1.46784277e-04, 1.56281428e-04, ...,
#          1.80695141e-04, 1.81084564e-04, 1.55123274e-04],
#         [3.79481471e-05, 1.63512124e-04, 1.72772298e-04, ...,
#          1.82217431e-04, 1.82534604e-04, 1.57267629e-04],
#         ...,
#         [1.62400209e-04, 5.53582431e-04, 7.35288338e-04, ...,
#          2.89511041e-04, 2.28424379e-04, 5.63377249e-05],
#         [1.41913961e-04, 4.18935290e-04, 6.70506131e-04, ...,
#          1.43270078e-04, 1.20863447e-04, 2.55292395e-05],
#         [9.41500436e-05, 1.87264757e-04, 3.27731567e-04, ...,
#          7.02261803e-06, 4.33494940e-06, 0.00000000e+00]]),
#  array([[4.57539460e-05, 6.31746626e-05, 6.58334316e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.00177791e-04, 1.34568389e-04, 1.36741644e-04, ...,
#          1.08662732e-06, 0.00000000e+00, 0.00000000e+00],
#         [1.13483195e-04, 1.48578946e-04, 1.47792875e-04, ...,
#          1.00651745e-04, 6.80182461e-05, 3.22173440e-05],
#         ...,
#         [1.35181062e-04, 1.74449924e-04, 1.70669848e-04, ...,
#          1.24152951e-04, 1.40695118e-04, 1.17552268e-04],
#         [1.35366020e-04, 1.74334325e-04, 1.70138094e-04, ...,
#          9.67560707e-05, 9.71259863e-05, 7.11625294e-05],
#         [9.92067621e-05, 1.34637749e-04, 1.35863094e-04, ...,
#          7.05151769e-06, 1.89581787e-06, 1.15598651e-08]]),
#  array([[0.00000000e+00, 9.24050042e-23, 6.93591904e-08, ...,
#          1.06350759e-06, 2.39431633e-20, 0.00000000e+00],
#         [2.89343423e-05, 7.40640555e-05, 7.99364670e-05, ...,
#          3.74886424e-05, 3.26103794e-05, 2.40098398e-05]])]

# %%
# Target for example: systole only
label = pd.DataFrame(labels)
label.columns = ['Id','Systole','Diastole']
actual_value = np.round(label.loc[np.array(study_index)-1,'Systole']).astype(int)
Y_train = actual_value

# one-hot encode
label_train = np.zeros([len(Y_train), 600])
for i in range(len(Y_train)):
    value = Y_train.iloc[i]
    label_train[i,value-1] = 1

# %%
# predictor
X_train_average = np.array(X_train_average).reshape([-1, 64, 64, 1])
X_train_average.shape
# Out:
# (493, 64, 64, 1)

# %%
X_train_average.reshape([493,64*64])
#X_train_average[0].reshape([64*64])
# Out:
# array([[3.97517083e-05, 8.01098650e-05, 9.76968658e-05, ...,
#         3.64064612e-05, 1.23637203e-05, 3.48218705e-06],
#        [7.49716013e-05, 1.04846965e-04, 1.06214449e-04, ...,
#         1.20071548e-04, 8.47548596e-05, 3.52917864e-05],
#        [4.76960033e-05, 6.58681112e-05, 6.73708936e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [4.12918380e-05, 7.92544349e-05, 2.14921011e-04, ...,
#         1.32499173e-04, 1.51919747e-04, 9.71491061e-05],
#        [0.00000000e+00, 1.55981113e-05, 2.10800562e-05, ...,
#         9.32495783e-07, 8.75980887e-07, 0.00000000e+00],
#        [5.24817874e-06, 5.71057335e-05, 7.46420488e-05, ...,
#         3.74886424e-05, 3.26103794e-05, 2.40098398e-05]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train_average, label_train, test_size=0.33, random_state=42)
np.savetxt('X_train.csv', X_train.reshape((330,64*64)), delimiter=',')
np.savetxt('X_test.csv', X_test.reshape((163,64*64)), delimiter=',')
np.savetxt('y_train.csv',y_train, delimiter=',')
np.savetxt('y_test.csv', y_test, delimiter=',')

# %%
from __future__ import division, print_function, absolute_import

import tflearn
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.estimator import regression

# %%
network = input_data(shape=[None, 64, 64, 1], name='input')
network = conv_2d(network, 32, 3, activation='relu', regularizer="L2")
network = max_pool_2d(network, 2)
network = conv_2d(network, 64, 3, activation='relu', regularizer="L2")
network = max_pool_2d(network, 2)
network = fully_connected(network, 128, activation='tanh')
network = dropout(network, 0.8)
network = fully_connected(network, 256, activation='tanh')
network = dropout(network, 0.8)
network = fully_connected(network, 600, activation='softmax')
# Out:
# WARNING:tensorflow:From /Users/dogspro/anaconda3/lib/python3.6/site-packages/tflearn/initializations.py:119: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.

# %%
network = regression(network, optimizer='adam', learning_rate=0.01,
                     loss='categorical_crossentropy', name='target')
# Out:
# WARNING:tensorflow:From /Users/dogspro/anaconda3/lib/python3.6/site-packages/tflearn/objectives.py:66: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
model = tflearn.DNN(network, tensorboard_verbose=0)
model.fit({'input': X_train}, {'target': y_train}, n_epoch=1,
           validation_set=({'input': X_test}, {'target': y_train}),
           snapshot_step=100, show_metric=True, run_id='convnet')
# Out:
# ---------------------------------
# Run id: convnet
# Log directory: /tmp/tflearn_logs/
# INFO:tensorflow:Summary name Accuracy/ (raw) is illegal; using Accuracy/__raw_ instead.
# ---------------------------------
# Training samples: 330
# Validation samples: 163
# --
